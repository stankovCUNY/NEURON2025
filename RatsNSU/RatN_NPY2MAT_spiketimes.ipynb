# %%
import numpy as np
import scipy.io

data     = np.load('RatN_Day2_2019-10-11_03-58-54.neurons.npy',allow_pickle=True)
dataDict = data.tolist()
del dataDict['metadata']

scipy.io.savemat('RatN_Day2_2019-10-11_03-58-54.neurons.mat', dataDict)

# %%
import numpy as np
import scipy.io

data     = np.load('RatN_Day2_2019-10-11_03-58-54.neurons.stable.npy',allow_pickle=True)
dataDict = data.tolist()
del dataDict['waveforms_amplitude']

scipy.io.savemat('RatN_Day2_2019-10-11_03-58-54.neurons.stable.mat', dataDict)

# %%
import numpy as np
import scipy.io
import pandas

paradigm     = np.load('RatN_Day2_2019-10-11_03-58-54.paradigm.npy',allow_pickle=True)
paradigmDict = paradigm.tolist()

scipy.io.savemat('RatN_Day2_2019-10-11_03-58-54.paradigm.mat', 
                 {col_name : paradigmDict['epochs'][col_name].values for 
                  col_name in paradigmDict['epochs'].columns.values})

# %%
import numpy as np
import scipy.io

probegroup     = np.load('RatN_Day2_2019-10-11_03-58-54.probegroup.npy',allow_pickle=True)
probegroupDict = probegroup.tolist()

scipy.io.savemat('RatN_Day2_2019-10-11_03-58-54.probegroup.mat', 
                 {col_name : probegroupDict['data'][col_name].values for 
                  col_name in probegroupDict['data'].columns.values})
