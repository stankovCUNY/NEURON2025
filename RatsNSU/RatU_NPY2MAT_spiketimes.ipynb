# %%
import numpy as np
import scipy.io

data     = np.load('RatU_Day2NSD_2021-07-24_08-16-38.neurons.npy',allow_pickle=True)
dataDict = data.tolist()
del dataDict['metadata']

scipy.io.savemat('RatU_Day2NSD_2021-07-24_08-16-38.neurons.mat', dataDict)

# %%
import numpy as np
import scipy.io

data     = np.load('RatU_Day2NSD_2021-07-24_08-16-38.neurons.stable.npy',allow_pickle=True)
dataDict = data.tolist()
del dataDict['waveforms_amplitude']

scipy.io.savemat('RatU_Day2NSD_2021-07-24_08-16-38.neurons.stable.mat', dataDict)

# %%
import numpy as np
import scipy.io
import pandas

paradigm     = np.load('RatU_Day2NSD_2021-07-24_08-16-38.paradigm.npy',allow_pickle=True)
paradigmDict = paradigm.tolist()

scipy.io.savemat('RatU_Day2NSD_2021-07-24_08-16-38.paradigm.mat', 
                 {col_name : paradigmDict['epochs'][col_name].values for 
                  col_name in paradigmDict['epochs'].columns.values})

# %%
import numpy as np
import scipy.io

probegroup     = np.load('RatU_Day2NSD_2021-07-24_08-16-38.probegroup.npy',allow_pickle=True)
probegroupDict = probegroup.tolist()

scipy.io.savemat('RatU_Day2NSD_2021-07-24_08-16-38.probegroup.mat', 
                 {col_name : probegroupDict['data'][col_name].values for 
                  col_name in probegroupDict['data'].columns.values})
