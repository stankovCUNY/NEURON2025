# %%
import numpy as np
import scipy.io

data     = np.load('RatS-Day2NSD-2020-11-27_10-22-29.neurons.npy',allow_pickle=True)
dataDict = data.tolist()
del dataDict['metadata']

scipy.io.savemat('RatS-Day2NSD-2020-11-27_10-22-29.neurons.mat', dataDict)

# %%
import numpy as np
import scipy.io

data     = np.load('RatS-Day2NSD-2020-11-27_10-22-29.neurons.stable.npy',allow_pickle=True)
dataDict = data.tolist()
del dataDict['waveforms_amplitude']

scipy.io.savemat('RatS-Day2NSD-2020-11-27_10-22-29.neurons.stable.mat', dataDict)

# %%
import numpy as np
import scipy.io
import pandas

paradigm     = np.load('RatS-Day2NSD-2020-11-27_10-22-29.paradigm.npy',allow_pickle=True)
paradigmDict = paradigm.tolist()

scipy.io.savemat('RatS-Day2NSD-2020-11-27_10-22-29.paradigm.mat', 
                 {col_name : paradigmDict['epochs'][col_name].values for 
                  col_name in paradigmDict['epochs'].columns.values})

# %%
import numpy as np
import scipy.io

probegroup     = np.load('RatS-Day2NSD-2020-11-27_10-22-29.probegroup.npy',allow_pickle=True)
probegroupDict = probegroup.tolist()

scipy.io.savemat('RatS-Day2NSD-2020-11-27_10-22-29.probegroup.mat', 
                 {col_name : probegroupDict['data'][col_name].values for 
                  col_name in probegroupDict['data'].columns.values})

# %%
# Out:
# array({'data':           x     y  contact_id channel_id  shank_id connected  probe_id
# 0       0.0   0.0         0.0         25       0.0      True       0.0
# 1       0.0  15.0         1.0          0       0.0      True       0.0
# 2       0.0  30.0         2.0          8       0.0      True       0.0
# 3       0.0  45.0         3.0         20       0.0     False       0.0
# 4       0.0  60.0         4.0          3       0.0      True       0.0
# ..      ...   ...         ...        ...       ...       ...       ...
# 123  2331.5  37.5       123.0        180      13.0      True       1.0
# 124  2331.5  52.5       124.0        179      13.0      True       1.0
# 125  2331.5  67.5       125.0        176      13.0      True       1.0
# 126  2331.5  82.5       126.0        177      13.0      True       1.0
# 127  2331.5  97.5       127.0        178      13.0      True       1.0
#
# [191 rows x 7 columns], 'metadata': {}}, dtype=object)
